# %%
import matplotlib.pyplot as plt
import numpy as np

colors = ["#5F0F40", "#C9DAEA", "#84A07C", "#E36414", "#39A9DB", "#0081A7", "#284B63", "#FFD449"]

# %% [markdown]
# # Plot Spatial log-likelihood

# %%
# 数据
nstpp25 = [-2.8385,-2.8385,-2.8385] # pending line 561
autoSTPP25 = [-10.668428421020508, -10.644194602966309, -10.61408805847168]
deepSTPP25 = [-11.320114135742188, -11.39246940612793, -11.332357406616211]
etas25 = [-4.44817, -4.44817, -4.44817]
possion25 = [-14.0341, -14.0341, -14.0341]

# 计算每组数据的均值和标准差
mean_nstpp25 = np.mean(nstpp25)
std_nstppP25 = np.std(nstpp25)

mean_autoSTPP25 = np.mean(autoSTPP25)
std_autoSTPP25 = np.std(autoSTPP25)

mean_deepSTPP25 = np.mean(deepSTPP25)
std_deepSTPP25 = np.std(deepSTPP25)

mean_etas25 = np.mean(etas25)
std_etas25 = np.std(etas25)

mean_possion25 = np.mean(possion25)
std_possion25 = np.std(possion25)

# X, Y 数据
x = [0, 1, 2, 3, 4]
y = [mean_nstpp25,mean_autoSTPP25, mean_deepSTPP25, mean_etas25, mean_possion25]
y_std = [std_nstppP25,std_autoSTPP25, std_deepSTPP25, std_etas25, std_possion25]

# 设置颜色
colors = ["#FFD449","#5F0F40", "#84A07C", "#E36414", "#39A9DB"]

# 创建图形和坐标轴对象，并设置背景色
fig, ax = plt.subplots()
ax.set_facecolor('#f0f0f0')  # 设置绘图区的背景色

# x轴标签
xticklabels = ['NSTPP','AutoSTPP', 'DeepSTPP', 'ETAS', 'POSSION']
ax.set_xticks(x)
ax.set_xticklabels(xticklabels)

# 设置 y 轴范围和标签
ax.grid(True)
ax.set_ylim((-18, -2))
ax.set_title('CENC')
ax.set_ylabel('Spatial log-likelihood')


# 绘制每个点及其对应的误差棒
for i in range(len(x)):
    ax.scatter(x[i], y[i], s=100, color=colors[i],zorder=100)  # 散点
    ax.errorbar(x[i], y[i], yerr=y_std[i], fmt='o', color=colors[i], capsize=10,zorder=100)  # 误差棒

plt.savefig('2.spatial—log-likelihood.png', dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# 数据
nstpp25 = [0.7252,0.7252,0.7252]
autoSTPP25 = [0.7223646640777588, 0.7151394486427307, 0.7177554965019226]
deepSTPP25 = [0.6637280583381653, 0.7321946620941162, 0.666939377784729]
etas25 = [0.784752, 0.784752, 0.784752]
possion25 = [0.410438, 0.410438, 0.410438]

# 计算每组数据的均值和标准差
mean_nstpp25 = np.mean(nstpp25)
std_nstppP25 = np.std(nstpp25)

mean_autoSTPP25 = np.mean(autoSTPP25)
std_autoSTPP25 = np.std(autoSTPP25)

mean_deepSTPP25 = np.mean(deepSTPP25)
std_deepSTPP25 = np.std(deepSTPP25)

mean_etas25 = np.mean(etas25)
std_etas25 = np.std(etas25)

mean_possion25 = np.mean(possion25)
std_possion25 = np.std(possion25)

# X, Y 数据
x = [0, 1, 2, 3, 4]
y = [mean_nstpp25,mean_autoSTPP25, mean_deepSTPP25, mean_etas25, mean_possion25]
y_std = [std_nstppP25 ,std_autoSTPP25, std_deepSTPP25, std_etas25, std_possion25]

# 设置颜色
colors = ["#FFD449", "#5F0F40", "#84A07C", "#E36414", "#39A9DB"]

# 创建图形和坐标轴对象，并设置背景色
fig, ax = plt.subplots()
ax.set_facecolor('#f0f0f0')  # 设置绘图区的背景色

# x轴标签
xticklabels = ['NSTPP','AutoSTPP', 'DeepSTPP', 'ETAS', 'POSSION']
ax.set_xticks(x)
ax.set_xticklabels(xticklabels)

# 设置 y 轴范围和标签
ax.grid(True)
ax.set_ylim((0.0,1.0))
ax.set_title('CENC')
ax.set_ylabel('Temporal log-likelihood')


# 绘制每个点及其对应的误差棒
for i in range(len(x)):
    ax.scatter(x[i], y[i], s=100, color=colors[i],zorder=100)  # 散点
    ax.errorbar(x[i], y[i], yerr=y_std[i], fmt='o', color=colors[i], capsize=10,zorder=100)  # 误差棒

plt.savefig('1.temporal—log-likelihood.png', dpi=300, format='png', bbox_inches='tight')

plt.show()

# %%
#data preprocess
##ETAS
#temporal
etas15_temporal = [2.538967676033916]
etas20_temporal = [1.639523816648067]
etas25_temporal = [0.7847517509818742]
etas30_temporal = [-0.14127555623549845]
etas35_temporal = [-1.024926779941944]

#spatial
etas15_spatial = [-1.9489082143105099]
etas20_spatial = [-2.485742346255885]
etas25_spatial = [-4.4481735381159755]
etas30_spatial = [-6.0858937839604055]
etas35_spatial  = [-7.970711953114396]

etas_temporal = [etas15_temporal,etas20_temporal,etas25_temporal,etas30_temporal,etas35_temporal]
etas_spatial = [etas15_spatial,etas20_spatial,etas25_spatial,etas30_spatial,etas35_spatial]
#==========================================================================================================================

##Possion
#temporal
possion15_temporal = [2.0605868451475184]
possion20_temporal = [1.3570222966556174]
possion25_temporal = [0.41043803616746166]
possion30_temporal = [-0.6809785186179321]
possion35_temporal = [-1.7300244465143477]

#spatial
possion15_spatial  = [-14.034073153510287]
possion20_spatial  = [-14.034073153510288]
possion25_spatial  = [-14.034073153510287]
possion30_spatial  = [-14.034073153510287]
possion35_spatial = [-14.034073153510287]

possion_temporal = [possion15_temporal,possion20_temporal,possion25_temporal,possion30_temporal,possion35_temporal]
possion_spatial = [possion15_spatial,possion20_spatial,possion25_spatial,possion30_spatial,possion35_spatial]
#==========================================================================================================================



##deepSTPP
#temporal
deepSTPP15_temporal = [2.3570144176483154, 2.3117318153381348, 2.4161458015441895]
deepSTPP20_temporal = [1.5737509727478027, 1.5801339149475098, 1.5738403797149658]
deepSTPP25_temporal = [0.6637280583381653, 0.7321946620941162, 0.666939377784729]
deepSTPP30_temporal = [-0.4466467499732971, -0.4376624822616577, -0.46679461002349854]
deepSTPP35_temporal = [-1.5523555278778076, -1.5551666021347046, -1.5261669158935547]

#spatial
deepSTPP15_spatial = [-11.760746002197266, -11.777376174926758, -11.783357620239258]
deepSTPP20_spatial = [-11.483707427978516, -11.509393692016602, -11.478975296020508]
deepSTPP25_spatial = [-11.320114135742188, -11.39246940612793, -11.332357406616211]
deepSTPP30_spatial = [-11.292485237121582, -11.332782745361328, -11.301454544067383]
deepSTPP35_spatial = [-11.353093147277832, -11.386582374572754, -11.395541191101074]

deepSTPP_temporal = [deepSTPP15_temporal, deepSTPP20_temporal,deepSTPP25_temporal,deepSTPP30_temporal,deepSTPP35_temporal]
deepSTPP_spatial = [deepSTPP15_spatial, deepSTPP20_spatial,deepSTPP25_spatial,deepSTPP30_spatial,deepSTPP35_spatial]
#==========================================================================================================================

##autoSTPP
#temporal
autoSTPP15_temporal = [2.262864589691162, 2.353874444961548, 2.3898041248321533]
autoSTPP20_temporal = [1.603998064994812, 1.5901514291763306, 1.5301109552383423]
autoSTPP25_temporal = [0.7186861038208008, 0.7277538776397705, 0.7169878482818604]
autoSTPP30_temporal = [-0.3216346502304077, -0.3181144595146179, -0.30488285422325134]
autoSTPP35_temporal = [-1.3497265577316284, -1.3766502141952515, -1.3864128589630127]

#spatial
autoSTPP15_spatial = [-11.177560806274414, -11.246427536010742, -11.23995590209961]
autoSTPP20_spatial = [-10.855466842651367, -10.820329666137695, -10.758448600769043]
autoSTPP25_spatial = [-10.627814292907715, -10.682869911193848, -10.615121841430664]
autoSTPP30_spatial = [-10.854621887207031, -10.864609718322754, -10.807071685791016]
autoSTPP35_spatial = [-11.781633377075195, -11.738430976867676, -11.76269817352295]

autoSTPP_temporal = [autoSTPP15_temporal,autoSTPP20_temporal,autoSTPP25_temporal,autoSTPP30_temporal,autoSTPP35_temporal]
autoSTPP_spatial = [autoSTPP15_spatial,autoSTPP20_spatial,autoSTPP25_spatial,autoSTPP30_spatial,autoSTPP35_spatial]
#==========================================================================================================================

#计算每组数据的平均值
mean_etas_temporal = [np.mean(data) for data in etas_temporal]
mean_etas_spatial = [np.mean(data) for data in etas_spatial]
mean_possion_temporal = [np.mean(data) for data in possion_temporal]
mean_possion_spatial= [np.mean(data) for data in possion_spatial]

mean_deepSTPP_temporal = [np.mean(data) for data in deepSTPP_temporal]
mean_deepSTPP_spatial = [np.mean(data) for data in deepSTPP_spatial]
mean_autoSTPP_temporal = [np.mean(data) for data in autoSTPP_temporal]
mean_autoSTPP_spatial = [np.mean(data) for data in autoSTPP_spatial]


# 输出结果
print("Mean of etas_temporal:", mean_etas_temporal)
print("Mean of etas_spatial:", mean_etas_spatial)
print("Mean of possion_temporal:", mean_possion_temporal)
print("Mean of possion_spatial:", mean_possion_spatial)
print("Mean of deepSTPP_temporal:", mean_deepSTPP_temporal)
print("Mean of deepSTPP_spatial:", mean_deepSTPP_spatial)
print("Mean of autoSTPP_temporal:", mean_autoSTPP_temporal)
print("Mean of autoSTPP_spatial:", mean_autoSTPP_spatial)
# Out:
# Mean of etas_temporal: [2.538967676033916, 1.639523816648067, 0.7847517509818742, -0.14127555623549845, -1.024926779941944]
# Mean of etas_spatial: [-1.9489082143105099, -2.485742346255885, -4.4481735381159755, -6.0858937839604055, -7.970711953114396]
# Mean of possion_temporal: [2.0605868451475184, 1.3570222966556174, 0.41043803616746166, -0.6809785186179321, -1.7300244465143477]
# Mean of possion_spatial: [-14.034073153510287, -14.034073153510288, -14.034073153510287, -14.034073153510287, -14.034073153510287]
# Mean of deepSTPP_temporal: [2.36163067817688, 1.5759084224700928, 0.6876206994056702, -0.45036794741948444, -1.5445630153020222]
# Mean of deepSTPP_spatial: [-11.773826599121094, -11.490692138671875, -11.348313649495443, -11.308907508850098, -11.378405570983887]
# Mean of autoSTPP_temporal: [2.3355143864949546, 1.5747534831364949, 0.7211426099141439, -0.314877321322759, -1.3709298769632976]
# ...

# %% [markdown]
#  plot temporal data

# %%
# 绘制时间曲线数据
print("Mean of etas_temporal:", mean_etas_temporal)
print("Mean of possion_temporal:", mean_possion_temporal)
print("Mean of deepSTPP_temporal:", mean_deepSTPP_temporal)
print("Mean of autoSTPP_temporal:", mean_autoSTPP_temporal)

# X, Y 数据
xetas = [1.5,2.0,2.5,3.0,3.5]
xpossion = [1.5,2.0,2.5,3.0,3.5]
xdeep = [1.5, 2.0, 2.5, 3.0, 3.5]
xauto = [1.5, 2.0, 2.5, 3.0, 3.5]
ydeep = mean_deepSTPP_temporal
yauto = mean_autoSTPP_temporal
yetas = mean_etas_temporal
ypossion = mean_possion_temporal

# 设置颜色
colors = ["#5F0F40", "#84A07C", "#E36414", "#39A9DB"]

# 创建图形和坐标轴对象，并设置背景色
fig, ax = plt.subplots()
ax.set_facecolor('#f0f0f0')  # 设置绘图区的背景色

# x轴标签
ax.set_xticks(xauto)

# 设置 y 轴范围和标签
ax.grid(True)
ax.set_ylim((-3.0,4.0))
ax.set_title('CENC')
ax.set_ylabel('Temporal log-likelihood')
ax.set_xlabel('Mc')


#plot
ax.plot(xauto,yauto,lw=1.0,label='autoSTPP',marker='o', color='#5F0F40',zorder=101)
ax.plot(xdeep,ydeep,lw=1.0,label='deepSTPP',marker='o', color='#84A07C')
ax.plot(xetas,yetas,lw=1.0,label='etas',marker='o', color='#E36414')
ax.plot(xpossion,ypossion,lw=1.0,label='possion',marker='o', color='#39A9DB')

# 添加图例
plt.legend()

plt.savefig('3.temporal—log-likelihood-curve.png', dpi=300, format='png', bbox_inches='tight')

plt.show()
# Out:
# Mean of etas_temporal: [2.538967676033916, 1.639523816648067, 0.7847517509818742, -0.14127555623549845, -1.024926779941944]
# Mean of possion_temporal: [2.0605868451475184, 1.3570222966556174, 0.41043803616746166, -0.6809785186179321, -1.7300244465143477]
# Mean of deepSTPP_temporal: [2.36163067817688, 1.5759084224700928, 0.6876206994056702, -0.45036794741948444, -1.5445630153020222]
# Mean of autoSTPP_temporal: [2.3355143864949546, 1.5747534831364949, 0.7211426099141439, -0.314877321322759, -1.3709298769632976]

# %% [markdown]
# # plot spatial data

# %%
# 绘制时间曲线数据
print("Mean of etas_temporal:", mean_etas_spatial)
print("Mean of possion_temporal:", mean_possion_spatial)
print("Mean of deepSTPP_temporal:", mean_deepSTPP_spatial)
print("Mean of autoSTPP_temporal:", mean_autoSTPP_spatial)

# X, Y 数据
xetas = [1.5,2.0,2.5,3.0,3.5]
xpossion = [1.5,2.0,2.5,3.0,3.5]
xdeep = [1.5, 2.0, 2.5, 3.0, 3.5]
xauto = [1.5, 2.0, 2.5, 3.0, 3.5]
ydeep = mean_deepSTPP_spatial
yauto = mean_autoSTPP_spatial
yetas = mean_etas_spatial
ypossion = mean_possion_spatial

# 设置颜色
colors = ["#5F0F40", "#84A07C", "#E36414", "#39A9DB"]

# 创建图形和坐标轴对象，并设置背景色
fig, ax = plt.subplots()
ax.set_facecolor('#f0f0f0')  # 设置绘图区的背景色

# x轴标签
ax.set_xticks(xauto)

# 设置 y 轴范围和标签
ax.grid(True)
# ax.set_ylim((-14.0,-9.0))
ax.set_title('CENC')
ax.set_ylabel('Spatial log-likelihood')
ax.set_xlabel('Mc')


#plot
ax.plot(xauto,yauto,lw=1.0,label='autoSTPP',marker='o', color='#5F0F40',zorder=101)
ax.plot(xdeep,ydeep,lw=1.0,label='deepSTPP',marker='o', color='#84A07C')
ax.plot(xetas,yetas,lw=1.0,label='etas',marker='o', color='#E36414')
ax.plot(xpossion,ypossion,lw=1.0,label='possion',marker='o', color='#39A9DB')

# 添加图例
plt.legend()

plt.savefig('4.spatial—log-likelihood-curve.png', dpi=300, format='png', bbox_inches='tight')

plt.show()
# Out:
# Mean of etas_temporal: [-1.9489082143105099, -2.485742346255885, -4.4481735381159755, -6.0858937839604055, -7.970711953114396]
# Mean of possion_temporal: [-14.034073153510287, -14.034073153510288, -14.034073153510287, -14.034073153510287, -14.034073153510287]
# Mean of deepSTPP_temporal: [-11.773826599121094, -11.490692138671875, -11.348313649495443, -11.308907508850098, -11.378405570983887]
# Mean of autoSTPP_temporal: [-11.221314748128256, -10.811415036519369, -10.641935348510742, -10.842101097106934, -11.760920842488607]
